# %%
myDict = {
        'labels': ['Level of crime', 'Crime  increasing in the past 3 years', 'Worries home broken and things stolen', 'Worries being mugged or robbed',
           'Worries car stolen', 'Worries things from car stolen', 'Worries attacked', 'Worries being insulted',
           'skin color, ethnic origin, gender or religion crime', 'Problem people using or dealing drugs',
           'Problem property crimes such as vandalism and theft', 'Problem violent crimes such as assault and armed robbery',
           'Problem corruption and bribery', 'Safety walking alone during daylight', 'Safety walking alone during night'],
    
        'Mexico City': [79.4, 80.43, 58.14, 76.23,
                          65.79, 69.37, 62.94, 52.04,
                          29.37, 69.05, 74.48, 80.26,
                          88.42, 48.49, 20.02],
    
         'Jo\'burg City': [89.47, 81.06, 79.27, 81.37,
                           77.60, 81.32, 75.59, 63.39,
                           66.20, 71.49, 82.83, 88.52,
                           92.10, 30.15, 8.49]
         }

# %%
import pandas as pd

df = pd.DataFrame(myDict)
df = df.set_index('labels')

# %%
df.head()
# Out:
#                                        Mexico City  Jo'burg City
# labels
# Level of crime                               79.40         89.47
# Crime  increasing in the past 3 years        80.43         81.06
# Worries home broken and things stolen        58.14         79.27
# Worries being mugged or robbed               76.23         81.37
# Worries car stolen                           65.79         77.60

# %%
import matplotlib.pyplot as plt

df.plot(kind='bar',figsize=(12,6))
plt.title("Jo'burg vs Mexico - Crime Rate")
plt.xlabel('Types of Crime')
plt.ylabel('Crime Level')
plt.savefig('Downloads/JvsM.png', dpi=1000)
plt.show()
